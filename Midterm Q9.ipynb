# %%
import networkx
graph = networkx.Graph()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd downloads
# Out:
# /Users/nicktan/Downloads

# %%
word_assoc = networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=str, data=[('weight', float)] )

# %%
print(list(word_assoc))
# Out:
# ['A', 'ALPHABET', 'AN', 'AND', 'APPLE', 'B', 'GRADE', 'GREAT', 'LETTER', 'ONE', 'PLUS', 'THE', 'WORD', 'Z', 'AARDVARK', 'ANIMAL', 'ANT', 'ANTEATER', 'CONFUSED', 'DICTIONARY', 'FUR', 'MUSIC', 'NOSE', 'PINK_PANTHER', 'ROAD_KILL', 'SHELL', 'UGLY', 'ZOO', 'ABDOMEN', 'BELLY', 'BODY', 'CRAMP', 'CRUNCHES', 'INTESTINE', 'MUSCLE', 'ORGAN', 'PAIN', 'SEX', 'SIT_UPS', 'SIX_PACK', 'STOMACH', 'ABDUCT', 'ADDUCT', 'ALIEN', 'CAPTURE', 'CHILD', 'HARASS', 'KIDNAP', 'KIDNAPPER', 'MISSING', 'OPEN', 'STEAL', 'TAKE', 'ABILITY', 'ABLE', 'ATHLETE', 'CAN', 'CAPABILITY', 'CAPACITY', 'COMPETENCE', 'DISABILITY', 'DO', 'INABILITY', 'KNOWLEDGE', 'KNOW_HOW', 'MIND', 'PHYSICAL', 'POTENTIAL', 'POWER', 'SKILL', 'SPORT', 'STRENGTH', 'TALENT', 'TO', 'UNABLE', 'WORK', 'BODIED', 'CAIN', 'CAPABLE', 'DISABLED', 'EASY', 'HANDICAPPED', 'READY', 'STRONG', 'WELL', 'WILLING', 'ABNORMAL', 'CRAZY', 'DEFORMED', 'DIFFERENT', 'INSANE', 'ME', 'NORMAL', 'ODD', 'PSYCHOLOGY', 'RETARDED', 'STRANGE', 'UNCOMMON', 'UNUSUAL', 'WEIRD', 'ABOVE'
# ...

# %%
print(list(word_assoc)[1])
# Out:
# ALPHABET

# %%
print (list(word_assoc)[5].count(''))
# Out:
# 2

# %%
number = []
for x in range(10616):
    number.append(list(word_assoc)[x].count('')-1)
    

_ = plt.hist(number, bins = 19, log=True, color='purple')

# %%
# Most words have length of around 5-7, peaking at around length of 6. Graph shaped like bell-curve, but there are more words with shorter lengths
