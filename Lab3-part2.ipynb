# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
n = int(input('Enter a number: '))

for i in range(n):
    if i < n-1:
        G.add_edges_from([(i, i+1)])
    if i == n-1:
        G.add_edges_from([(i,0)])
        G.add_edges_from([(i,1)])

for i in range(n):
    if i < n-2:
        G.add_edges_from([(i, i+2)])
    if i == n-2:
        G.add_edges_from([(i, 0)])

pos = nx.circular_layout(G)

nx.draw_networkx(G, pos)

plt.show()
# Out:
# Enter a number: 10

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
n = int(input('Enter a number: '))

for i in range(n):
    if i < n-1:
        G.add_edges_from([(i, i+1)])
    if i == n-1:
        G.add_edges_from([(i,0)])
        G.add_edges_from([(i,1)])

for i in range(n):
    if i < n-2:
        G.add_edges_from([(i, i+2)])
    if i == n-2:
        G.add_edges_from([(i, 0)])

pos = nx.circular_layout(G)

nx.draw_networkx(G, pos)

plt.show()
# Out:
# Enter a number: 12

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
n = int(input('Enter a number: '))

for i in range(n):
    if i < n-1:
        G.add_edges_from([(i, i+1)])
    if i == n-1:
        G.add_edges_from([(i,0)])
        G.add_edges_from([(i,1)])

for i in range(n):
    if i < n-2:
        G.add_edges_from([(i, i+2)])
    if i == n-2:
        G.add_edges_from([(i, 0)])

pos = nx.circular_layout(G)

nx.draw_networkx(G, pos)

plt.show()
# Out:
# Enter a number: 6

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
n = int(input('Enter a number: '))

for i in range(n):
    if i < n-1:
        G.add_edges_from([(i, i+1)])
    if i == n-1:
        G.add_edges_from([(i,0)])
        G.add_edges_from([(i,1)])

for i in range(n):
    if i < n-2:
        G.add_edges_from([(i, i+2)])
    if i == n-2:
        G.add_edges_from([(i, 0)])

pos = nx.circular_layout(G)

nx.draw_networkx(G, pos)

plt.show()
# Out:
# Enter a number: 8
