# %%
3+5

# %%
a = 7
for i < a:
    print("Who?")

# %%
a = 10
for i in range(a):
    print("Who?")

# %%
clear

# %%
a += 3
print(a)

# %%
import networkx

# %%
graph = networkx.graph()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-db4fb3f76cbe> in <module>()
# ----> 1 graph = networkx.graph()
#
# TypeError: 'module' object is not callable

# %% [raw]
# graph - networkx.Graph()

# %%
graph
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cad80f3b6f4e> in <module>()
# ----> 1 graph
#
# NameError: name 'graph' is not defined

# %%
graph = networkx.graph()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-db4fb3f76cbe> in <module>()
# ----> 1 graph = networkx.graph()
#
# TypeError: 'module' object is not callable

# %% [raw]
# import networkx

# %% [raw]
# import networkx

# %%
graph = networkx.graph()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-db4fb3f76cbe> in <module>()
# ----> 1 graph = networkx.graph()
#
# TypeError: 'module' object is not callable

# %%
graph.add_node(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-92ffb5bcffd4> in <module>()
# ----> 1 graph.add_node(1)
#
# NameError: name 'graph' is not defined

# %%
import networkx

# %%
graph = networkx.Graph()

# %%
graph

# %%
graph.add_node(1)

# %%
graph.add_node(2)

# %%
graph.add_edge(1,2)

# %%
networks.draw(graph)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f200235d1a63> in <module>()
# ----> 1 networks.draw(graph)
#
# NameError: name 'networks' is not defined

# %%
networkx.draw(graph)
# Out:
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
graph.add_node(3, 4, ,5 , 6, 7)
# Out:
#   File "<ipython-input-11-f494d9008d87>", line 1
#     graph.add_node(3, 4, ,5 , 6, 7)
#                          ^
# SyntaxError: invalid syntax

# %%
graph.add_node(2, 3, 4, 5, 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a33453c75a69> in <module>()
# ----> 1 graph.add_node(2, 3, 4, 5, 6)
#
# TypeError: add_node() takes from 2 to 3 positional arguments but 6 were given

# %%
graph.add_node(2)

# %%
graph.add_node(3)

# %%
ply.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-faa74ea1aa67> in <module>()
# ----> 1 ply.show()
#
# NameError: name 'ply' is not defined

# %%
plt.show()

# %%
# %matplotlib inLine
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-15dfbe713f90> in <module>()
# ----> 1 get_ipython().magic('matplotlib inLine')
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
# ...

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
networkx.draw(graph)
# Out:
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
plt.plot(range(5))

# %%
plt.plot(range(10))

# %%
#make a loop:
for i in range(3,6):
    graph.add_node(i)
    graph.add_edge(1,i)
#make some node
#connect the nodes

# %%
networkx.draw(graph)
# Out:
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
networkx.draw(graph)
# Out:
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
networkx.draw(graph)
# Out:
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
networkx.draw(graph)
# Out:
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=)
# Out:
#   File "<ipython-input-29-37919909e999>", line 1
#     networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=)
#                                                                                                        ^
# SyntaxError: invalid syntax

# %%
graph.nodes()
# Out:
# [1, 2, 3, 4, 5]

# %%
graph.add_node("asdf")

# %%
graph.add_node((2,3,4))

# %%
graph.nodes()
# Out:
# [1, 2, 3, 4, 5, 'asdf', (2, 3, 4)]

# %%
word_association = networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=str, data=[('weight', float)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-9f9339e4178f> in <module>()
# ----> 1 word_association = networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=str, data=[('weight', float)])
#
# <decorator-gen-291> in read_edgelist(path, comments, delimiter, create_using, nodetype, data, edgetype, encoding)
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/utils/decorators.py in _open_file(func, *args, **kwargs)
#     196         if is_string_like(path):
#     197             ext = splitext(path)[1]
# --> 198             fobj = _dispatch_dict[ext](path, mode=mode)
#     199             close_fobj = True
#     200         elif hasattr(path, 'read'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'word_association_graph_DSF.txt'

# %%
word_association = networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=str, data=[('weight', float)])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-9f9339e4178f> in <module>()
# ----> 1 word_association = networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=str, data=[('weight', float)])
#
# <decorator-gen-291> in read_edgelist(path, comments, delimiter, create_using, nodetype, data, edgetype, encoding)
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/networkx/utils/decorators.py in _open_file(func, *args, **kwargs)
#     196         if is_string_like(path):
#     197             ext = splitext(path)[1]
# --> 198             fobj = _dispatch_dict[ext](path, mode=mode)
#     199             close_fobj = True
#     200         elif hasattr(path, 'read'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'word_association_graph_DSF.txt'

# %%
# !pwd
# Out:
# /Users/nicktan

# %%
ls
# Out:
# AndroidStudioProjects/  Library/                VirtualBox VMs/
# Applications/           Movies/                 anaconda/
# CytoscapeConfiguration/ Music/                  angr_ctf/
# Desktop/                Pictures/               repos/
# Documents/              Public/
# Downloads/              Untitled.ipynb

# %%
cd Downloads/
# Out:
# /Users/nicktan/Downloads

# %%
word_association = networkx.read_edgelist('word_association_graph_DSF.txt', create_using=networkx.DiGraph(), nodetype=str, data=[('weight', float)])

# %%
word_association.number_of_nodes(), word_association.number_of_edges()
# Out:
# (10616, 72171)

# %%
word_association.edges()
# Out:
# [('A', 'ALPHABET'),
#  ('A', 'AN'),
#  ('A', 'AND'),
#  ('A', 'APPLE'),
#  ('A', 'B'),
#  ('A', 'GRADE'),
#  ('A', 'GREAT'),
#  ('A', 'LETTER'),
#  ('A', 'ONE'),
#  ('A', 'PLUS'),
#  ('A', 'THE'),
#  ('A', 'WORD'),
#  ('A', 'Z'),
#  ('ALPHABET', 'A'),
#  ('ALPHABET', 'ABC'),
#  ('ALPHABET', 'CEREAL'),
#  ('ALPHABET', 'ENGLISH'),
#  ('ALPHABET', 'KINDERGARTEN'),
#  ('ALPHABET', 'LETTERS'),
#  ('ALPHABET', 'NUMBERS'),
#  ('ALPHABET', 'SCHOOL'),
#  ('ALPHABET', 'SOUP'),
#  ('ALPHABET', 'SPELL'),
#  ('ALPHABET', 'TWENTY_SIX'),
#  ('APPLE', 'BANANA'),
#  ('APPLE', 'BITE'),
#  ('APPLE', 'COMPUTER'),
#  ('APPLE', 'CORE'),
#  ('APPLE', 'CRISP'),
#  ('APPLE', 'EAT'),
#  ('APPLE', 'FOOD'),
#  ('APPLE', 'FRUIT'),
#  ('APPLE', 'GREEN'),
#  ('APPLE', 'ORANGE'),
#  ('APPLE', 'PEACH'),
#  ('APPLE', 'PEAR'),
#  ('APPLE', 'PIE'),
#  ('APPLE', 'RED'),
#  ('APPLE', 'SEED'),
#  ('APPLE', 'TREE'),
#  ('APPLE', 'WORM'),
#  ('GRADE', 'A'),
#  ('GRADE', 'ANXIETY'),
#  ('GRADE', 'AVERAGE'),
# ...

# %%
for source, target in word_association.edges():
# Out:
#   File "<ipython-input-42-09b32938ab3d>", line 1
#     for source, target in word_association.edges():
#                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
for source, target in word_association.edges():
    print(source, target)
# Out:
# A ALPHABET
# A AN
# A AND
# A APPLE
# A B
# A GRADE
# A GREAT
# A LETTER
# A ONE
# A PLUS
# A THE
# A WORD
# A Z
# ALPHABET A
# ALPHABET ABC
# ALPHABET CEREAL
# ALPHABET ENGLISH
# ALPHABET KINDERGARTEN
# ALPHABET LETTERS
# ALPHABET NUMBERS
# ALPHABET SCHOOL
# ALPHABET SOUP
# ALPHABET SPELL
# ALPHABET TWENTY_SIX
# APPLE BANANA
# APPLE BITE
# APPLE COMPUTER
# APPLE CORE
# APPLE CRISP
# APPLE EAT
# APPLE FOOD
# APPLE FRUIT
# APPLE GREEN
# APPLE ORANGE
# APPLE PEACH
# APPLE PEAR
# APPLE PIE
# APPLE RED
# APPLE SEED
# APPLE TREE
# APPLE WORM
# GRADE A
# GRADE ANXIETY
# GRADE AVERAGE
# GRADE CLASS
# GRADE CLASSIFICATION
# GRADE GOOD
# GRADE LETTER
# GRADE LEVEL
# GRADE MARK
# GRADE PASS
# GRADE SCHOOL
# GRADE SCORE
# GRADE TEST
# GRADE WORK
# GREAT AWESOME
# GREAT AWFUL
# GREAT BAD
# GREAT BEST
# GREAT BIG
# GREAT GOOD
# GREAT GREATER
# GREAT HUGE
# GREAT LARGE
# GREAT LITTLE
# GREAT MAGNIFICENT
# GREAT MAN
# GREAT POOR
# GREAT SMALL
# GREAT SUPER
# GREAT TERRIBLE
# GREAT TERRIFIC
# ...

# %%
a_dictionary = {} #keys: words, value: num. of occurence

# %%
a_dictionary = {} #keys: words, value: num. of occurence
    for source, target in word_association.edges():
        if source in a_dictionary:
            a_dictionary[source] += 1
            else:
                a_dictionary[source] = 1
# Out:
#   File "<ipython-input-45-c93c366d22f7>", line 2
#     for source, target in word_association.edges():
#     ^
# IndentationError: unexpected indent

# %%
a_dictionary = {} #keys: words, value: num. of occurence
for source, target in word_association.edges():
    if source in a_dictionary:
        a_dictionary[source] += 
    else:
        a_dictionary[source] = 1
# Out:
#   File "<ipython-input-46-b0523700eab9>", line 4
#     a_dictionary[source] +=
#                             ^
# SyntaxError: invalid syntax

# %%
a_dictionary = {} #keys: words, value: num. of occurence
for source, target in word_association.edges():
    if source in a_dictionary:
        a_dictionary[source] += 1
    else:
        a_dictionary[source] = 1

# %%
plt.plot(list(sorted(a_dictionary.values())))

# %%
plt.hist(list(sorted(a_dictionary.values())))
# Out:
# (array([  103.,   334.,   736.,  1472.,   992.,   761.,   479.,   107.,
#            27.,     7.]),
#  array([  1. ,   4.3,   7.6,  10.9,  14.2,  17.5,  20.8,  24.1,  27.4,
#          30.7,  34. ]),
#  <a list of 10 Patch objects>)

# %%
# %matplotlib inline

# %%
plt.plot(list(sorted(a_dictionary.values())), bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-17ed931355e3> in <module>()
# ----> 1 plt.plot(list(sorted(a_dictionary.values())), bins=20)
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ...

# %%
plt.plot(list(sorted(a_dictionary.values())), bins=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-021e47ce330d> in <module>()
# ----> 1 plt.plot(list(sorted(a_dictionary.values())), bins=100)
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ...

# %%
x = plt.plot(list(sorted(a_dictionary.values())))

# %%
x = plt.hist(list(sorted(a_dictionary.values())), bin = 100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-94131deacc15> in <module>()
# ----> 1 x = plt.hist(list(sorted(a_dictionary.values())), bin = 100)
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3079                       histtype=histtype, align=align, orientation=orientation,
#    3080                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3081                       stacked=stacked, data=data, **kwargs)
#    3082     finally:
#    3083         ax._hold = washold
#
# /Users/nicktan/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
_ * plt.hist(list(sorted(a_dictionary.values())), bins=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-4a89a765a5c4> in <module>()
# ----> 1 _ * plt.hist(list(sorted(a_dictionary.values())), bins=100)
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
_ = plt.hist(list(sorted(a_dictionary.values())), bins=100)

# %%
_ = plt.hist(list(sorted(a_dictionary.values())), bins=50)

# %%
_ = plt.hist(list(sorted(a_dictionary.values())), bins=35)

# %%
plt.hist(list(sorted(a_dictionary.values())), bins=35)
# Out:
# (array([   1.,   13.,   21.,   68.,   70.,  118.,  146.,  226.,  231.,
#          279.,  355.,  340.,  395.,  382.,  351.,  316.,  325.,    0.,
#          297.,  254.,  210.,  175.,  124.,  105.,   75.,   52.,   31.,
#           24.,   14.,   12.,    1.,    4.,    0.,    2.,    1.]),
#  array([  1.        ,   1.94285714,   2.88571429,   3.82857143,
#           4.77142857,   5.71428571,   6.65714286,   7.6       ,
#           8.54285714,   9.48571429,  10.42857143,  11.37142857,
#          12.31428571,  13.25714286,  14.2       ,  15.14285714,
#          16.08571429,  17.02857143,  17.97142857,  18.91428571,
#          19.85714286,  20.8       ,  21.74285714,  22.68571429,
#          23.62857143,  24.57142857,  25.51428571,  26.45714286,
#          27.4       ,  28.34285714,  29.28571429,  30.22857143,
#          31.17142857,  32.11428571,  33.05714286,  34.        ]),
#  <a list of 35 Patch objects>)

# %%
plt.hist(list(sorted(a_dictionary.values())), bins=34)
# Out:
# (array([   1.,   13.,   21.,   68.,   70.,  118.,  146.,  226.,  231.,
#          279.,  355.,  340.,  395.,  382.,  351.,  316.,  325.,  297.,
#          254.,  210.,  175.,  124.,  105.,   75.,   52.,   31.,   24.,
#           14.,   12.,    1.,    4.,    0.,    2.,    1.]),
#  array([  1.        ,   1.97058824,   2.94117647,   3.91176471,
#           4.88235294,   5.85294118,   6.82352941,   7.79411765,
#           8.76470588,   9.73529412,  10.70588235,  11.67647059,
#          12.64705882,  13.61764706,  14.58823529,  15.55882353,
#          16.52941176,  17.5       ,  18.47058824,  19.44117647,
#          20.41176471,  21.38235294,  22.35294118,  23.32352941,
#          24.29411765,  25.26470588,  26.23529412,  27.20588235,
#          28.17647059,  29.14705882,  30.11764706,  31.08823529,
#          32.05882353,  33.02941176,  34.        ]),
#  <a list of 34 Patch objects>)

# %%
max(a_dictionary.values())
# Out:
# 34

# %%
min(a_dictionary.values())
# Out:
# 1

# %%
for source, target out word_association.edges():
    print(source, target)
# Out:
#   File "<ipython-input-1-acdf2abdd701>", line 1
#     for source, target out word_association.edges():
#                          ^
# SyntaxError: invalid syntax
