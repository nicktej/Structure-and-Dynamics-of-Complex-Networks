# %%
import networkx
import matplotlib.pyplot as plt
from networkx.utils import powerlaw_sequence
# %matplotlib inline

# %%
G = networkx.powerlaw_cluster_graph(10, 1, 1)

networkx.draw_networkx(G)
plt.show()

print(G.number_of_edges())
print(networkx.average_clustering(G))
print(networkx.closeness_centrality(G))
print(G.degree())
# Out:
# 9
# 0.0
# {0: 0.5294117647058824, 1: 0.8181818181818182, 2: 0.47368421052631576, 3: 0.47368421052631576, 4: 0.5294117647058824, 5: 0.36, 6: 0.47368421052631576, 7: 0.47368421052631576, 8: 0.36, 9: 0.47368421052631576}
# {0: 2, 1: 7, 2: 1, 3: 1, 4: 2, 5: 1, 6: 1, 7: 1, 8: 1, 9: 1}

# %%
G = networkx.powerlaw_cluster_graph(10, 2, 0.5)
closeness = 0
neighbors = 0
networkx.draw_networkx(G)
plt.show()

closeness = sum(networkx.closeness_centrality(G).values()) / 10
neighbors = sum(networkx.average_neighbor_degree(G).values()) / 10
print(G.number_of_edges())
print(networkx.average_clustering(G))
print(closeness)
print(neighbors)
print(G.degree().values())
# Out:
# 16
# 0.7694444444444445
# 0.6255357142857143
# 5.188888888888888
# dict_values([4, 2, 9, 3, 2, 3, 2, 2, 3, 2])

# %%
G = networkx.powerlaw_cluster_graph(10, 2, 1)

networkx.draw_networkx(G)
plt.show()

print(G.number_of_edges())
print(networkx.average_clustering(G))
print(networkx.closeness_centrality(G))
print(G.degree())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-66a92dce6094> in <module>()
# ----> 1 G = networkx.powerlaw_cluster_graph(10, 2, 1)
#       2
#       3 networkx.draw_networkx(G)
#       4 plt.show()
#       5
#
# NameError: name 'networkx' is not defined

# %%
G = networkx.powerlaw_cluster_graph(10, 2, 1)

networkx.draw_networkx(G)
plt.show()

print(G.number_of_edges())
print(networkx.average_clustering(G))
print(networkx.closeness_centrality(G))
print(G.degree())
# Out:
# 16
# 0.7266666666666667
# {0: 0.6923076923076923, 1: 0.42857142857142855, 2: 0.6428571428571429, 3: 0.6428571428571429, 4: 0.47368421052631576, 5: 0.6, 6: 0.42857142857142855, 7: 0.5, 8: 0.47368421052631576, 9: 0.4090909090909091}
# {0: 5, 1: 2, 2: 5, 3: 4, 4: 2, 5: 5, 6: 2, 7: 3, 8: 2, 9: 2}

# %%
G = networkx.powerlaw_cluster_graph(10, 5, 1)

networkx.draw_networkx(G)
plt.show()

print(G.number_of_edges())
print(networkx.average_clustering(G))
print(networkx.closeness_centrality(G))
print(G.degree())
# Out:
# 25
# 0.7596825396825396
# {0: 0.6923076923076923, 1: 0.6, 2: 0.5625, 3: 0.6428571428571429, 4: 0.5294117647058824, 5: 1.0, 6: 0.9, 7: 0.8181818181818182, 8: 0.75, 9: 0.6923076923076923}
# {0: 5, 1: 3, 2: 2, 3: 4, 4: 1, 5: 9, 6: 8, 7: 7, 8: 6, 9: 5}

# %%
G = networkx.powerlaw_cluster_graph(100, 10, 1)
av_clust = 0
neighbors = 0
closeness = 0

for i in range(100):
    networkx.draw_networkx(G)
    av_clust = av_clust + networkx.average_clustering(G)
    neighbors = sum(networkx.average_neighbor_degree(G).values()) / 100
    closeness = sum(networkx.closeness_centrality(G).values()) / 100

av_clust = av_clust / 100

print(G.number_of_edges(), av_clust, neighbors, closeness)
# Out:
# 897 0.5697090363451397 26.332669653123535 0.5299665439561232

# %%
_ = plt.hist(list(networkx.average_neighbor_degree(G).values()), bins=25, log=True)

# %%
_ = plt.hist(list(networkx.closeness_centrality(G).values()), bins=20, log=True)

# %%
print(list(G.degree().values()))
# Out:
# [26, 22, 13, 9, 18, 29, 6, 5, 10, 4, 59, 67, 64, 47, 34, 37, 34, 34, 16, 26, 29, 24, 31, 15, 23, 17, 24, 22, 18, 10, 32, 21, 41, 23, 26, 15, 24, 23, 15, 25, 15, 18, 15, 19, 12, 16, 20, 19, 17, 14, 15, 13, 14, 11, 14, 23, 14, 13, 14, 16, 12, 12, 16, 11, 17, 13, 10, 11, 11, 14, 16, 13, 13, 10, 11, 11, 11, 13, 13, 11, 11, 10, 12, 13, 12, 12, 12, 11, 11, 10, 10, 10, 10, 10, 10, 10, 11, 10, 10, 10]

# %%
G = networkx.powerlaw_cluster_graph(100, 10, 1)
av_clust = 0
d_neighbors = {}
d_closeness = {}
neighbors = 0
closeness = 0

for i in range(100):
    networkx.draw_networkx(G)
    av_clust = av_clust + networkx.average_clustering(G)
    d_neighbors = 
    neighbors = sum(networkx.average_neighbor_degree(G).values()) / 100
    closeness = sum(networkx.closeness_centrality(G).values()) / 100

av_clust = av_clust / 100

print(G.number_of_edges(), av_clust, neighbors, closeness)
